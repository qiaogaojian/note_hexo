# %% [markdown]
# # 高等数学基础

# %% [markdown]
# ## 三角函数

# %% [markdown]
# ### Sin

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

x = np.linspace(-10,10,1000)
a = np.sin(x)
b = np.cos(x)
c = np.tan(x)
d = 1/np.tan(x)

plt.figure(figsize=(10,5))
plt.plot(x,a,label='$sin(x)$',color='green',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2,2)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ### Cos

# %%
plt.figure(figsize=(10,5))
plt.plot(x,b,label='$cos(x)$',color='red',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2,2)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ### Tan

# %%
plt.figure(figsize=(10,5))
plt.plot(x,c,label='$tan(x)$',color='blue',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2,2)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ### Cot

# %%
plt.figure(figsize=(10,5))
plt.plot(x,d,label='$cot(x)$',color='blue',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2,2)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ## 指数函数

# %% [markdown]
# ### $a^2$

# %%
x = np.linspace(-10,10,1000)
a = np.power(x,2)

plt.figure(figsize=(10,5))
plt.plot(x,a,label='$sin(x)$',color='green',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2,2)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ### $a^3$

# %%
x = np.linspace(-10,10,1000)
a = np.power(x,3)

plt.figure(figsize=(10,5))
plt.plot(x,a,label='$sin(x)$',color='green',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-2,2)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ## 幂函数

# %%
x = np.linspace(-10,10,1000)
y = np.power(2,x)

plt.figure(figsize=(10,5))
plt.plot(x,y,label='$sin(x)$',color='green',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-3,3)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()

# %% [markdown]
# ## 对数函数

# %%
def log(x,b):
    return np.log(x) / np.log(b)

x = np.linspace(0.001,10,1000)
y = log(x,1/2)

plt.figure(figsize=(10,5))
plt.plot(x,y,label='$sin(x)$',color='green',linewidth=0.5)

plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-3,3)
ax=plt.gca()  
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))  
ax.spines['left'].set_position(('axes',0.5))
plt.show()
